# %% [markdown]
# # Import module

# %%
from src.geocoder import SshiGeocoder

# %% [markdown]
# # Initiate module

# %%
sshi_geocoder = SshiGeocoder(country_code='ID')

# %% [markdown]
# # Define Variables

# %%
list_locations = ['jatinegara', 'bidaracina']
shp_file_path = 'data/shp/INDO_DESA_2023_1.shp'
data_csv = 'data/location.csv'
data_excel = 'data/location.xlsx'

# %% [markdown]
# # Geocode

# %% [markdown]
# ## List

# %%
data_locations = sshi_geocoder.geocode_locations(list_locations)
data_locations.head()
# Out:
# geocode locations: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
#      location   longitude  latitude  \
# 0  jatinegara  109.246244 -7.063125
# 1  jatinegara  109.246244 -7.063125
# 2  jatinegara  109.246244 -7.063125
# 3  jatinegara  109.246244 -7.063125
# 4  jatinegara  109.246244 -7.063125
#
#                                            address                    geometry
# 0  Jatinegara, Tegal, Jawa Tengah, Jawa, Indonesia  POINT (109.24624 -7.06313)
# 1  Jatinegara, Tegal, Jawa Tengah, Jawa, Indonesia  POINT (109.24624 -7.06313)
# 2  Jatinegara, Tegal, Jawa Tengah, Jawa, Indonesia  POINT (109.24624 -7.06313)
# 3  Jatinegara, Tegal, Jawa Tengah, Jawa, Indonesia  POINT (109.24624 -7.06313)
# 4  Jatinegara, Tegal, Jawa Tengah, Jawa, Indonesia  POINT (109.24624 -7.06313)

# %% [markdown]
# ## File (.csv/.xlsx)

# %%
import pandas as pd
df = pd.read_csv(data_csv)
df.head()
# Out:
#      BAYI_TMPT_LAHIR  JML
# 0           TILUNTOB    4
# 1           HOLBOTA     1
# 2          NETETNANA    4
# 3  PASIR PUTIH BARAT    1
# 4     TANJUNG SENANG   13

# %%
data_locations = sshi_geocoder.geocode_locations(
    locations=df, location_column='BAYI_TMPT_LAHIR')
data_locations.head()
# Out:
# geocode locations: 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]
#      BAYI_TMPT_LAHIR  JML   longitude  latitude  \
# 0           TILUNTOB    4         NaN       NaN
# 1           HOLBOTA     1         NaN       NaN
# 2          NETETNANA    4         NaN       NaN
# 3  PASIR PUTIH BARAT    1  100.494227  1.730198
# 4     TANJUNG SENANG   13  104.918587 -4.879586
#
#                                              address  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Pasir Putih Barat, Bagan Sinembah, Rokan Hilir...
# 4  Tanjung Senang, Lampung Utara, Lampung, Sumate...
#
#                      geometry
# 0                        None
# 1                        None
# 2                        None
# 3    POINT (100.49423 1.7302)
# 4  POINT (104.91859 -4.87959)

# %% [markdown]
# # Load Adm Boundaries (.shp)

# %%
data_polygon = sshi_geocoder.load_shapefile(shp_file_path)
data_polygon.head()
# Out:
#   kdprov kdkab kdkec kddesa      iddesa  nmprov               nmkab  \
# 0     81    08   082    006  8108082006  MALUKU   MALUKU BARAT DAYA
# 1     81    07   020    024  8107020024  MALUKU  SERAM BAGIAN TIMUR
# 2     81    08   080    010  8108080010  MALUKU   MALUKU BARAT DAYA
# 3     81    03   050    022  8103050022  MALUKU       MALUKU TENGAH
# 4     81    03   141    012  8103141012  MALUKU       MALUKU TENGAH
#
#                nmkec     nmdesa sumber periode  \
# 0    DAWELOOR DAWERA  NURNYAMAN    BPS  2023_1
# 1        SERAM TIMUR      KELLU    BPS  2023_1
# 2        BABAR TIMUR     YATOKE    BPS  2023_1
# 3             AMAHAI      RUTAH    BPS  2023_1
# 4  SERAM UTARA BARAT    SALEMAN    BPS  2023_1
#
#                                             geometry
# 0  POLYGON ((130.09024 -7.77802, 130.09031 -7.778...
# 1  MULTIPOLYGON (((130.85928 -3.87563, 130.85927 ...
# 2  POLYGON ((129.8505 -7.84217, 129.85182 -7.8421...
# 3  POLYGON ((128.96645 -3.36159, 128.96549 -3.361...
# 4  POLYGON ((129.08063 -3.00877, 129.08064 -3.008...

# %% [markdown]
# # Overlay

# %%
overlayed_data = sshi_geocoder.get_intersect(data_location=data_locations, polygon=data_polygon)

# %%
overlayed_data
# Out:
#      BAYI_TMPT_LAHIR  JML   longitude  latitude  \
# 3  PASIR PUTIH BARAT    1  100.494227  1.730198
# 4     TANJUNG SENANG   13  104.918587 -4.879586
# 5     TANJUNG SENANG   13  104.918587 -4.879586
#
#                                              address  \
# 3  Pasir Putih Barat, Bagan Sinembah, Rokan Hilir...
# 4  Tanjung Senang, Lampung Utara, Lampung, Sumate...
# 5  Tanjung Senang, Lampung Utara, Lampung, Sumate...
#
#                point_geometry  index_polygon kdprov kdkab kdkec kddesa  \
# 3    POINT (100.49423 1.7302)          69336     14    09   023    010
# 4  POINT (104.91859 -4.87959)          73978     18    06   050    004
# 5  POINT (104.91859 -4.87959)          73978     18    06   050    004
#
#        iddesa   nmprov          nmkab          nmkec             nmdesa  \
# 3  1409023010     RIAU    ROKAN HILIR     BALAI JAYA  PASIR PUTIH BARAT
# 4  1806050004  LAMPUNG  LAMPUNG UTARA  ABUNG SELATAN          CANDI MAS
# 5  1806050004  LAMPUNG  LAMPUNG UTARA  ABUNG SELATAN          CANDI MAS
#
#   sumber periode                                   polygon_geometry
# 3    BPS  2023_1  POLYGON ((100.48338 1.71025, 100.48338 1.71026...
# 4    BPS  2023_1  POLYGON ((104.92573 -4.8571, 104.9249 -4.85818...
# 5    BPS  2023_1  POLYGON ((104.92573 -4.8571, 104.9249 -4.85818...

# %% [markdown]
# # Visualize

# %%
sshi_geocoder.visualize_gdf(overlayed_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6b431790f63fd1aa496681437f5b1cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6b431790f63fd1aa496681437f5b1cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6b431790f63fd1aa496681437f5b1cd = L.map(
#                 &quot;map_d6b431790f63fd1aa496681437f5b1cd&quot;,
#                 {
#                     center: [-2.6763245333333336, 103.44380023333333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f0b1e143bbbef464ef514ab01fc52f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f0b1e143bbbef464ef514ab01fc52f0.addTo(map_d6b431790f63fd1aa496681437f5b1cd);
#
#
#             var feature_group_40208c07d0e75ec6bf72b0c9d5c2e9ab = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_2f0a2aea78574ddf0fc8bf7fb4c2d2d6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_2f0a2aea78574ddf0fc8bf7fb4c2d2d6_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json